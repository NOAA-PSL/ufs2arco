# %%
import numpy as np
import matplotlib.pyplot as plt
import xarray as xr
import time

# %%
import subprocess
from collections import defaultdict

# %% [markdown]
# Note that it's not necessary to specify levels for "thermal" in GFS

# %%
hr = 0

levels = {}
for typeOfLevel in ["heightAboveGround", "heightAboveGroundLayer", "pressureFromGroundLayer", "isobaricInhPa"]:
    print(typeOfLevel)
    each_set_of_levels = []
    for fhr in [0, 6]:
        for suffix in ["", "b"]:
            output = subprocess.check_output([
                "grib_ls",
                "-p", "level,typeOfLevel",
                f"grib-store/gfs.0p25{suffix}.20180425{hr:02d}.f{fhr:03d}.grib2"
            ]).decode()
        
            each_set_of_levels.append(
                set(
                    int(line.split()[0]) for line in output.splitlines()
                    if typeOfLevel in line
                )
            )
    levels[typeOfLevel] = sorted(set().union(*each_set_of_levels))
    print(levels[typeOfLevel])
    print()
# Out:
# heightAboveGround
# [2, 10, 80, 100, 3000, 6000]
#
# heightAboveGroundLayer
# [3000, 6000]
#
# pressureFromGroundLayer
# [3000, 6000, 9000, 12000, 15000, 18000, 25500]
#
# isobaricInhPa
# [1, 2, 3, 5, 7, 10, 20, 30, 50, 70, 100, 125, 150, 175, 200, 225, 250, 275, 300, 325, 350, 375, 400, 425, 450, 475, 500, 525, 550, 575, 600, 625, 650, 675, 700, 725, 750, 775, 800, 825, 850, 875, 900, 925, 950, 975, 1000]

# %%
keys = [
    'surface',
    'planetaryBoundaryLayer',
    'isobaricInhPa',
    'meanSea',
    'depthBelowLandLayer',
    'heightAboveGround',
    'atmosphereSingleLayer',
    'heightAboveGroundLayer',
    'tropopause',
    'maxWind',
    'heightAboveSea',
    'isothermZero',
    'highestTroposphericFreezing',
    'pressureFromGroundLayer',
    'sigmaLayer',
    'sigma',
    'potentialVorticity',
    # only in forecast
    'lowCloudLayer',
    'middleCloudLayer',
    'highCloudLayer',
    'atmosphere',
    'convectiveCloudBottom',
    'lowCloudBottom',
    'middleCloudBottom',
    'highCloudBottom',
    'convectiveCloudTop',
    'lowCloudTop',
    'middleCloudTop',
    'highCloudTop',
    'convectiveCloudLayer',
    'boundaryLayerCloudLayer',
    'nominalTop',
]

# %%
for k in sorted(keys):
    print(f'\t"{k}"')
# Out:
# 	"atmosphere"
# 	"atmosphereSingleLayer"
# 	"boundaryLayerCloudLayer"
# 	"convectiveCloudBottom"
# 	"convectiveCloudLayer"
# 	"convectiveCloudTop"
# 	"depthBelowLandLayer"
# 	"heightAboveGround"
# 	"heightAboveGroundLayer"
# 	"heightAboveSea"
# 	"highCloudBottom"
# 	"highCloudLayer"
# 	"highCloudTop"
# 	"highestTroposphericFreezing"
# 	"isobaricInhPa"
# 	"isothermZero"
# 	"lowCloudBottom"
# 	"lowCloudLayer"
# 	"lowCloudTop"
# 	"maxWind"
# 	"meanSea"
# 	"middleCloudBottom"
# 	"middleCloudLayer"
# 	"middleCloudTop"
# 	"nominalTop"
# 	"planetaryBoundaryLayer"
# 	"potentialVorticity"
# 	"pressureFromGroundLayer"
# 	"sigma"
# 	"sigmaLayer"
# 	"surface"
# 	"tropopause"

# %%
def read_them(fbk, hr=0):
    """This one is geared toward comparing what's available in forecast vs analysis"""
    print(fbk)

    allvars = {}
    for fhr in [0, 6]:
        a = xr.open_dataset(
            f"grib-store/gfs.0p25.20180425{hr:02d}.f{fhr:03d}.grib2",
            engine="cfgrib",
            decode_timedelta=True,
            filter_by_keys=fbk,
        )
        
        b = xr.open_dataset(
            f"grib-store/gfs.0p25b.20180425{hr:02d}.f{fhr:03d}.grib2",
            engine="cfgrib",
            decode_timedelta=True,
            filter_by_keys=fbk,
        )
        xds = xr.merge([a,b])
        allvars[fhr] = set(list(a.data_vars)+list(b.data_vars))

    both = sorted(list( allvars[0].intersection(allvars[6]) ))
    both = {k: xds[k].attrs["long_name"] for k in both}
    only0 = sorted(list( allvars[0] - allvars[6] ))
    only0 = {k: xds[k].attrs["long_name"] for k in only0}
    only6 = sorted(list( allvars[6] - allvars[0] ))
    only6 = {k: xds[k].attrs["long_name"] for k in only6}
    print(f"\tBoth: {both}")
    print(f"\tAnalysis: {only0}")
    print(f"\tForecast: {only6}")
    return a, b

# %%
for typeOfLevel in sorted(keys):
    fbk = {"typeOfLevel": typeOfLevel}
    if typeOfLevel in levels:

        for level in levels[typeOfLevel]:
            fbk["level"] = level
            a, b = read_them(fbk)
#    elif typeOfLevel in stepTypes:
#        for stepType in stepTypes[typeOfLevel]:
#            fbk["stepType"] = stepType
#            prs, sfc = read_them(fbk)
#            
#        
    else:
        a, b = read_them(fbk)
# Out:
# {'typeOfLevel': 'atmosphere'}
# 	Both: {}
# 	Analysis: {}
# 	Forecast: {'tcc': 'Total Cloud Cover'}
# {'typeOfLevel': 'atmosphereSingleLayer'}
# 	Both: {'cwat': 'Cloud water', 'pwat': 'Precipitable water', 'r': 'Relative humidity', 'tozne': 'Total ozone'}
# 	Analysis: {}
# 	Forecast: {'cwork': 'Cloud work function'}
# {'typeOfLevel': 'boundaryLayerCloudLayer'}
# 	Both: {}
# 	Analysis: {}
# 	Forecast: {'tcc': 'Total Cloud Cover'}
# {'typeOfLevel': 'convectiveCloudBottom'}
# 	Both: {}
# 	Analysis: {}
# 	Forecast: {'pres': 'Pressure'}
# {'typeOfLevel': 'convectiveCloudLayer'}
# 	Both: {}
# 	Analysis: {}
# 	Forecast: {'tcc': 'Total Cloud Cover'}
# {'typeOfLevel': 'convectiveCloudTop'}
# 	Both: {}
# 	Analysis: {}
# 	Forecast: {'pres': 'Pressure'}
# {'typeOfLevel': 'depthBelowLandLayer'}
# 	Both: {'soill': 'Liquid volumetric soil moisture (non-frozen)', 'soilw': 'Volumetric soil moisture content', 'st': 'Soil temperature'}
# 	Analysis: {}
# 	Forecast: {}
# {'typeOfLevel': 'heightAboveGround', 'level': 2}
# 	Both: {'aptmp': 'Apparent temperature', 'd2m': '2 metre dewpoint temperature', 'r2': '2 metre relative humidity', 'sh2': '2 metre specific humidity', 't2m': '2 metre temperature'}
# 	Analysis: {}
# 	Forecast: {'tmax': 'Maximum temperature', 'tmin': 'Minimum temperature'}
# {'typeOfLevel': 'heightAboveGround', 'level': 10}
# 	Both: {'u10': '10 metre U wind component', 'v10': '10 metre V wind component'}
# 	Analysis: {}
# 	Forecast: {}
# {'typeOfLevel': 'heightAboveGround', 'level': 80}
# 	Both: {'pres': 'Pressure', 'q': 'Specific humidity', 't': 'Temperature', 'u': 'U component of wind', 'v': 'V component of wind'}
# 	Analysis: {}
# 	Forecast: {}
# {'typeOfLevel': 'heightAboveGround', 'level': 100}
# 	Both: {'t': 'Temperature', 'u100': '100 metre U wind component', 'v100': '100 metre V wind component'}
# 	Analysis: {}
# 	Forecast: {}
# {'typeOfLevel': 'heightAboveGround', 'level': 3000}
# 	Both: {}
# 	Analysis: {}
# 	Forecast: {}
# {'typeOfLevel': 'heightAboveGround', 'level': 6000}
# 	Both: {}
# 	Analysis: {}
# 	Forecast: {}
# {'typeOfLevel': 'heightAboveGroundLayer', 'level': 3000}
# 	Both: {'hlcy': 'Storm relative helicity'}
# 	Analysis: {}
# 	Forecast: {}
# {'typeOfLevel': 'heightAboveGroundLayer', 'level': 6000}
# 	Both: {'ustm': 'U-component storm motion', 'vstm': 'V-component storm motion'}
# 	Analysis: {}
# 	Forecast: {}
# {'typeOfLevel': 'heightAboveSea'}
# 	Both: {'t': 'Temperature', 'u': 'U component of wind', 'v': 'V component of wind'}
# 	Analysis: {}
# 	Forecast: {}
# {'typeOfLevel': 'highCloudBottom'}
# 	Both: {}
# 	Analysis: {}
# 	Forecast: {'avg_pres': 'Time-mean pressure'}
# {'typeOfLevel': 'highCloudLayer'}
# 	Both: {}
# 	Analysis: {}
# 	Forecast: {'tcc': 'Total Cloud Cover'}
# {'typeOfLevel': 'highCloudTop'}
# 	Both: {}
# 	Analysis: {}
# 	Forecast: {'avg_pres': 'Time-mean pressure', 'avg_t': 'Time-mean temperature'}
# {'typeOfLevel': 'highestTroposphericFreezing'}
# 	Both: {'gh': 'Geopotential height', 'r': 'Relative humidity'}
# 	Analysis: {}
# 	Forecast: {}
# {'typeOfLevel': 'isobaricInhPa', 'level': 1}
# 	Both: {'absv': 'Absolute vorticity', 'clwmr': 'Cloud mixing ratio', 'gh': 'Geopotential height', 'o3mr': 'Ozone mixing ratio', 'r': 'Relative humidity', 't': 'Temperature', 'u': 'U component of wind', 'v': 'V component of wind'}
# 	Analysis: {}
# 	Forecast: {}
# {'typeOfLevel': 'isobaricInhPa', 'level': 2}
# 	Both: {'absv': 'Absolute vorticity', 'clwmr': 'Cloud mixing ratio', 'gh': 'Geopotential height', 'o3mr': 'Ozone mixing ratio', 'r': 'Relative humidity', 't': 'Temperature', 'u': 'U component of wind', 'v': 'V component of wind'}
# 	Analysis: {}
# 	Forecast: {}
# {'typeOfLevel': 'isobaricInhPa', 'level': 3}
# 	Both: {'absv': 'Absolute vorticity', 'clwmr': 'Cloud mixing ratio', 'gh': 'Geopotential height', 'o3mr': 'Ozone mixing ratio', 'r': 'Relative humidity', 't': 'Temperature', 'u': 'U component of wind', 'v': 'V component of wind'}
# 	Analysis: {}
# 	Forecast: {}
# {'typeOfLevel': 'isobaricInhPa', 'level': 5}
# 	Both: {'absv': 'Absolute vorticity', 'clwmr': 'Cloud mixing ratio', 'gh': 'Geopotential height', 'o3mr': 'Ozone mixing ratio', 'r': 'Relative humidity', 't': 'Temperature', 'u': 'U component of wind', 'v': 'V component of wind'}
# 	Analysis: {}
# 	Forecast: {}
# {'typeOfLevel': 'isobaricInhPa', 'level': 7}
# 	Both: {'absv': 'Absolute vorticity', 'clwmr': 'Cloud mixing ratio', 'gh': 'Geopotential height', 'o3mr': 'Ozone mixing ratio', 'r': 'Relative humidity', 't': 'Temperature', 'u': 'U component of wind', 'v': 'V component of wind'}
# 	Analysis: {}
# 	Forecast: {}
# {'typeOfLevel': 'isobaricInhPa', 'level': 10}
# 	Both: {'absv': 'Absolute vorticity', 'gh': 'Geopotential height', 'o3mr': 'Ozone mixing ratio', 'r': 'Relative humidity', 't': 'Temperature', 'u': 'U component of wind', 'v': 'V component of wind'}
# 	Analysis: {}
# 	Forecast: {}
# {'typeOfLevel': 'isobaricInhPa', 'level': 20}
# 	Both: {'absv': 'Absolute vorticity', 'gh': 'Geopotential height', 'o3mr': 'Ozone mixing ratio', 'r': 'Relative humidity', 't': 'Temperature', 'u': 'U component of wind', 'v': 'V component of wind'}
# 	Analysis: {}
# 	Forecast: {}
# {'typeOfLevel': 'isobaricInhPa', 'level': 30}
# 	Both: {'absv': 'Absolute vorticity', 'gh': 'Geopotential height', 'o3mr': 'Ozone mixing ratio', 'r': 'Relative humidity', 't': 'Temperature', 'u': 'U component of wind', 'v': 'V component of wind'}
# 	Analysis: {}
# 	Forecast: {}
# {'typeOfLevel': 'isobaricInhPa', 'level': 50}
# 	Both: {'absv': 'Absolute vorticity', 'gh': 'Geopotential height', 'o3mr': 'Ozone mixing ratio', 'r': 'Relative humidity', 't': 'Temperature', 'u': 'U component of wind', 'v': 'V component of wind'}
# 	Analysis: {}
# 	Forecast: {}
# {'typeOfLevel': 'isobaricInhPa', 'level': 70}
# 	Both: {'absv': 'Absolute vorticity', 'gh': 'Geopotential height', 'o3mr': 'Ozone mixing ratio', 'r': 'Relative humidity', 't': 'Temperature', 'u': 'U component of wind', 'v': 'V component of wind'}
# 	Analysis: {}
# 	Forecast: {}
# {'typeOfLevel': 'isobaricInhPa', 'level': 100}
# 	Both: {'absv': 'Absolute vorticity', 'clwmr': 'Cloud mixing ratio', 'gh': 'Geopotential height', 'o3mr': 'Ozone mixing ratio', 'q': 'Specific humidity', 'r': 'Relative humidity', 't': 'Temperature', 'u': 'U component of wind', 'v': 'V component of wind', 'w': 'Vertical velocity'}
# 	Analysis: {}
# 	Forecast: {'ICSEV': 'Icing severity'}
# {'typeOfLevel': 'isobaricInhPa', 'level': 125}
# 	Both: {'absv': 'Absolute vorticity', 'clwmr': 'Cloud mixing ratio', 'gh': 'Geopotential height', 'q': 'Specific humidity', 'r': 'Relative humidity', 't': 'Temperature', 'u': 'U component of wind', 'v': 'V component of wind', 'w': 'Vertical velocity'}
# 	Analysis: {}
# 	Forecast: {}
# {'typeOfLevel': 'isobaricInhPa', 'level': 150}
# 	Both: {'absv': 'Absolute vorticity', 'clwmr': 'Cloud mixing ratio', 'gh': 'Geopotential height', 'o3mr': 'Ozone mixing ratio', 'q': 'Specific humidity', 'r': 'Relative humidity', 't': 'Temperature', 'u': 'U component of wind', 'v': 'V component of wind', 'w': 'Vertical velocity'}
# 	Analysis: {}
# 	Forecast: {'ICSEV': 'Icing severity'}
# {'typeOfLevel': 'isobaricInhPa', 'level': 175}
# 	Both: {'absv': 'Absolute vorticity', 'clwmr': 'Cloud mixing ratio', 'gh': 'Geopotential height', 'q': 'Specific humidity', 'r': 'Relative humidity', 't': 'Temperature', 'u': 'U component of wind', 'v': 'V component of wind', 'w': 'Vertical velocity'}
# 	Analysis: {}
# 	Forecast: {}
# {'typeOfLevel': 'isobaricInhPa', 'level': 200}
# 	Both: {'absv': 'Absolute vorticity', 'clwmr': 'Cloud mixing ratio', 'gh': 'Geopotential height', 'o3mr': 'Ozone mixing ratio', 'q': 'Specific humidity', 'r': 'Relative humidity', 't': 'Temperature', 'u': 'U component of wind', 'v': 'V component of wind', 'w': 'Vertical velocity'}
# 	Analysis: {}
# 	Forecast: {'ICSEV': 'Icing severity'}
# {'typeOfLevel': 'isobaricInhPa', 'level': 225}
# 	Both: {'absv': 'Absolute vorticity', 'clwmr': 'Cloud mixing ratio', 'gh': 'Geopotential height', 'q': 'Specific humidity', 'r': 'Relative humidity', 't': 'Temperature', 'u': 'U component of wind', 'v': 'V component of wind', 'w': 'Vertical velocity'}
# 	Analysis: {}
# 	Forecast: {}
# {'typeOfLevel': 'isobaricInhPa', 'level': 250}
# 	Both: {'absv': 'Absolute vorticity', 'clwmr': 'Cloud mixing ratio', 'gh': 'Geopotential height', 'o3mr': 'Ozone mixing ratio', 'q': 'Specific humidity', 'r': 'Relative humidity', 't': 'Temperature', 'u': 'U component of wind', 'v': 'V component of wind', 'w': 'Vertical velocity'}
# 	Analysis: {}
# 	Forecast: {'ICSEV': 'Icing severity'}
# {'typeOfLevel': 'isobaricInhPa', 'level': 275}
# 	Both: {'absv': 'Absolute vorticity', 'clwmr': 'Cloud mixing ratio', 'gh': 'Geopotential height', 'q': 'Specific humidity', 'r': 'Relative humidity', 't': 'Temperature', 'u': 'U component of wind', 'v': 'V component of wind', 'w': 'Vertical velocity'}
# 	Analysis: {}
# 	Forecast: {}
# {'typeOfLevel': 'isobaricInhPa', 'level': 300}
# 	Both: {'absv': 'Absolute vorticity', 'clwmr': 'Cloud mixing ratio', 'gh': 'Geopotential height', 'o3mr': 'Ozone mixing ratio', 'q': 'Specific humidity', 'r': 'Relative humidity', 't': 'Temperature', 'u': 'U component of wind', 'v': 'V component of wind', 'w': 'Vertical velocity'}
# 	Analysis: {}
# 	Forecast: {'ICSEV': 'Icing severity'}
# {'typeOfLevel': 'isobaricInhPa', 'level': 325}
# 	Both: {'absv': 'Absolute vorticity', 'clwmr': 'Cloud mixing ratio', 'gh': 'Geopotential height', 'q': 'Specific humidity', 'r': 'Relative humidity', 't': 'Temperature', 'u': 'U component of wind', 'v': 'V component of wind', 'w': 'Vertical velocity'}
# 	Analysis: {}
# 	Forecast: {}
# {'typeOfLevel': 'isobaricInhPa', 'level': 350}
# 	Both: {'absv': 'Absolute vorticity', 'clwmr': 'Cloud mixing ratio', 'gh': 'Geopotential height', 'o3mr': 'Ozone mixing ratio', 'q': 'Specific humidity', 'r': 'Relative humidity', 't': 'Temperature', 'u': 'U component of wind', 'v': 'V component of wind', 'w': 'Vertical velocity'}
# 	Analysis: {}
# 	Forecast: {'ICSEV': 'Icing severity'}
# {'typeOfLevel': 'isobaricInhPa', 'level': 375}
# 	Both: {'absv': 'Absolute vorticity', 'clwmr': 'Cloud mixing ratio', 'gh': 'Geopotential height', 'q': 'Specific humidity', 'r': 'Relative humidity', 't': 'Temperature', 'u': 'U component of wind', 'v': 'V component of wind', 'w': 'Vertical velocity'}
# 	Analysis: {}
# 	Forecast: {}
# {'typeOfLevel': 'isobaricInhPa', 'level': 400}
# 	Both: {'absv': 'Absolute vorticity', 'clwmr': 'Cloud mixing ratio', 'gh': 'Geopotential height', 'o3mr': 'Ozone mixing ratio', 'q': 'Specific humidity', 'r': 'Relative humidity', 't': 'Temperature', 'u': 'U component of wind', 'v': 'V component of wind', 'w': 'Vertical velocity'}
# 	Analysis: {}
# 	Forecast: {'ICSEV': 'Icing severity'}
# {'typeOfLevel': 'isobaricInhPa', 'level': 425}
# 	Both: {'absv': 'Absolute vorticity', 'clwmr': 'Cloud mixing ratio', 'gh': 'Geopotential height', 'q': 'Specific humidity', 'r': 'Relative humidity', 't': 'Temperature', 'u': 'U component of wind', 'v': 'V component of wind', 'w': 'Vertical velocity'}
# 	Analysis: {}
# 	Forecast: {}
# {'typeOfLevel': 'isobaricInhPa', 'level': 450}
# 	Both: {'absv': 'Absolute vorticity', 'clwmr': 'Cloud mixing ratio', 'gh': 'Geopotential height', 'q': 'Specific humidity', 'r': 'Relative humidity', 't': 'Temperature', 'u': 'U component of wind', 'v': 'V component of wind', 'w': 'Vertical velocity'}
# 	Analysis: {}
# 	Forecast: {'ICSEV': 'Icing severity'}
# {'typeOfLevel': 'isobaricInhPa', 'level': 475}
# 	Both: {'absv': 'Absolute vorticity', 'clwmr': 'Cloud mixing ratio', 'gh': 'Geopotential height', 'q': 'Specific humidity', 'r': 'Relative humidity', 't': 'Temperature', 'u': 'U component of wind', 'v': 'V component of wind', 'w': 'Vertical velocity'}
# 	Analysis: {}
# 	Forecast: {}
# {'typeOfLevel': 'isobaricInhPa', 'level': 500}
# 	Both: {'absv': 'Absolute vorticity', 'clwmr': 'Cloud mixing ratio', 'gh': 'Geopotential height', 'q': 'Specific humidity', 'r': 'Relative humidity', 't': 'Temperature', 'u': 'U component of wind', 'v': 'V component of wind', 'w': 'Vertical velocity', 'wavh5': '5-wave geopotential height'}
# 	Analysis: {}
# 	Forecast: {'ICSEV': 'Icing severity'}
# {'typeOfLevel': 'isobaricInhPa', 'level': 525}
# 	Both: {'absv': 'Absolute vorticity', 'clwmr': 'Cloud mixing ratio', 'gh': 'Geopotential height', 'q': 'Specific humidity', 'r': 'Relative humidity', 't': 'Temperature', 'u': 'U component of wind', 'v': 'V component of wind', 'w': 'Vertical velocity'}
# 	Analysis: {}
# 	Forecast: {}
# {'typeOfLevel': 'isobaricInhPa', 'level': 550}
# 	Both: {'absv': 'Absolute vorticity', 'clwmr': 'Cloud mixing ratio', 'gh': 'Geopotential height', 'q': 'Specific humidity', 'r': 'Relative humidity', 't': 'Temperature', 'u': 'U component of wind', 'v': 'V component of wind', 'w': 'Vertical velocity'}
# 	Analysis: {}
# 	Forecast: {'ICSEV': 'Icing severity'}
# {'typeOfLevel': 'isobaricInhPa', 'level': 575}
# 	Both: {'absv': 'Absolute vorticity', 'clwmr': 'Cloud mixing ratio', 'gh': 'Geopotential height', 'q': 'Specific humidity', 'r': 'Relative humidity', 't': 'Temperature', 'u': 'U component of wind', 'v': 'V component of wind', 'w': 'Vertical velocity'}
# 	Analysis: {}
# 	Forecast: {}
# {'typeOfLevel': 'isobaricInhPa', 'level': 600}
# 	Both: {'absv': 'Absolute vorticity', 'clwmr': 'Cloud mixing ratio', 'gh': 'Geopotential height', 'q': 'Specific humidity', 'r': 'Relative humidity', 't': 'Temperature', 'u': 'U component of wind', 'v': 'V component of wind', 'w': 'Vertical velocity'}
# 	Analysis: {}
# 	Forecast: {'ICSEV': 'Icing severity'}
# {'typeOfLevel': 'isobaricInhPa', 'level': 625}
# 	Both: {'absv': 'Absolute vorticity', 'clwmr': 'Cloud mixing ratio', 'gh': 'Geopotential height', 'q': 'Specific humidity', 'r': 'Relative humidity', 't': 'Temperature', 'u': 'U component of wind', 'v': 'V component of wind', 'w': 'Vertical velocity'}
# 	Analysis: {}
# 	Forecast: {}
# {'typeOfLevel': 'isobaricInhPa', 'level': 650}
# 	Both: {'absv': 'Absolute vorticity', 'clwmr': 'Cloud mixing ratio', 'gh': 'Geopotential height', 'q': 'Specific humidity', 'r': 'Relative humidity', 't': 'Temperature', 'u': 'U component of wind', 'v': 'V component of wind', 'w': 'Vertical velocity'}
# 	Analysis: {}
# 	Forecast: {'ICSEV': 'Icing severity'}
# {'typeOfLevel': 'isobaricInhPa', 'level': 675}
# 	Both: {'absv': 'Absolute vorticity', 'clwmr': 'Cloud mixing ratio', 'gh': 'Geopotential height', 'q': 'Specific humidity', 'r': 'Relative humidity', 't': 'Temperature', 'u': 'U component of wind', 'v': 'V component of wind', 'w': 'Vertical velocity'}
# 	Analysis: {}
# 	Forecast: {}
# {'typeOfLevel': 'isobaricInhPa', 'level': 700}
# 	Both: {'absv': 'Absolute vorticity', 'clwmr': 'Cloud mixing ratio', 'gh': 'Geopotential height', 'q': 'Specific humidity', 'r': 'Relative humidity', 't': 'Temperature', 'u': 'U component of wind', 'v': 'V component of wind', 'w': 'Vertical velocity'}
# 	Analysis: {}
# 	Forecast: {'ICSEV': 'Icing severity'}
# {'typeOfLevel': 'isobaricInhPa', 'level': 725}
# 	Both: {'absv': 'Absolute vorticity', 'clwmr': 'Cloud mixing ratio', 'gh': 'Geopotential height', 'q': 'Specific humidity', 'r': 'Relative humidity', 't': 'Temperature', 'u': 'U component of wind', 'v': 'V component of wind', 'w': 'Vertical velocity'}
# 	Analysis: {}
# 	Forecast: {}
# {'typeOfLevel': 'isobaricInhPa', 'level': 750}
# 	Both: {'absv': 'Absolute vorticity', 'clwmr': 'Cloud mixing ratio', 'gh': 'Geopotential height', 'q': 'Specific humidity', 'r': 'Relative humidity', 't': 'Temperature', 'u': 'U component of wind', 'v': 'V component of wind', 'w': 'Vertical velocity'}
# 	Analysis: {}
# 	Forecast: {'ICSEV': 'Icing severity'}
# {'typeOfLevel': 'isobaricInhPa', 'level': 775}
# 	Both: {'absv': 'Absolute vorticity', 'clwmr': 'Cloud mixing ratio', 'gh': 'Geopotential height', 'q': 'Specific humidity', 'r': 'Relative humidity', 't': 'Temperature', 'u': 'U component of wind', 'v': 'V component of wind', 'w': 'Vertical velocity'}
# 	Analysis: {}
# 	Forecast: {}
# {'typeOfLevel': 'isobaricInhPa', 'level': 800}
# 	Both: {'absv': 'Absolute vorticity', 'clwmr': 'Cloud mixing ratio', 'gh': 'Geopotential height', 'q': 'Specific humidity', 'r': 'Relative humidity', 't': 'Temperature', 'u': 'U component of wind', 'v': 'V component of wind', 'w': 'Vertical velocity'}
# 	Analysis: {}
# 	Forecast: {'ICSEV': 'Icing severity'}
# {'typeOfLevel': 'isobaricInhPa', 'level': 825}
# 	Both: {'absv': 'Absolute vorticity', 'clwmr': 'Cloud mixing ratio', 'gh': 'Geopotential height', 'q': 'Specific humidity', 'r': 'Relative humidity', 't': 'Temperature', 'u': 'U component of wind', 'v': 'V component of wind', 'w': 'Vertical velocity'}
# 	Analysis: {}
# 	Forecast: {}
# {'typeOfLevel': 'isobaricInhPa', 'level': 850}
# 	Both: {'absv': 'Absolute vorticity', 'clwmr': 'Cloud mixing ratio', 'gh': 'Geopotential height', 'q': 'Specific humidity', 'r': 'Relative humidity', 't': 'Temperature', 'u': 'U component of wind', 'v': 'V component of wind', 'w': 'Vertical velocity'}
# 	Analysis: {}
# 	Forecast: {'ICSEV': 'Icing severity'}
# {'typeOfLevel': 'isobaricInhPa', 'level': 875}
# 	Both: {'absv': 'Absolute vorticity', 'clwmr': 'Cloud mixing ratio', 'gh': 'Geopotential height', 'q': 'Specific humidity', 'r': 'Relative humidity', 't': 'Temperature', 'u': 'U component of wind', 'v': 'V component of wind', 'w': 'Vertical velocity'}
# 	Analysis: {}
# 	Forecast: {}
# {'typeOfLevel': 'isobaricInhPa', 'level': 900}
# 	Both: {'absv': 'Absolute vorticity', 'clwmr': 'Cloud mixing ratio', 'gh': 'Geopotential height', 'q': 'Specific humidity', 'r': 'Relative humidity', 't': 'Temperature', 'u': 'U component of wind', 'v': 'V component of wind', 'w': 'Vertical velocity'}
# 	Analysis: {}
# 	Forecast: {'ICSEV': 'Icing severity'}
# {'typeOfLevel': 'isobaricInhPa', 'level': 925}
# 	Both: {'absv': 'Absolute vorticity', 'clwmr': 'Cloud mixing ratio', 'gh': 'Geopotential height', 'q': 'Specific humidity', 'r': 'Relative humidity', 't': 'Temperature', 'u': 'U component of wind', 'v': 'V component of wind', 'w': 'Vertical velocity'}
# 	Analysis: {}
# 	Forecast: {}
# {'typeOfLevel': 'isobaricInhPa', 'level': 950}
# 	Both: {'absv': 'Absolute vorticity', 'clwmr': 'Cloud mixing ratio', 'gh': 'Geopotential height', 'q': 'Specific humidity', 'r': 'Relative humidity', 't': 'Temperature', 'u': 'U component of wind', 'v': 'V component of wind', 'w': 'Vertical velocity'}
# 	Analysis: {}
# 	Forecast: {'ICSEV': 'Icing severity'}
# {'typeOfLevel': 'isobaricInhPa', 'level': 975}
# 	Both: {'absv': 'Absolute vorticity', 'clwmr': 'Cloud mixing ratio', 'gh': 'Geopotential height', 'q': 'Specific humidity', 'r': 'Relative humidity', 't': 'Temperature', 'u': 'U component of wind', 'v': 'V component of wind', 'w': 'Vertical velocity'}
# 	Analysis: {}
# 	Forecast: {}
# {'typeOfLevel': 'isobaricInhPa', 'level': 1000}
# 	Both: {'absv': 'Absolute vorticity', 'clwmr': 'Cloud mixing ratio', 'gh': 'Geopotential height', 'q': 'Specific humidity', 'r': 'Relative humidity', 't': 'Temperature', 'u': 'U component of wind', 'v': 'V component of wind', 'w': 'Vertical velocity'}
# 	Analysis: {}
# 	Forecast: {'ICSEV': 'Icing severity'}
# {'typeOfLevel': 'isothermZero'}
# 	Both: {'gh': 'Geopotential height', 'r': 'Relative humidity'}
# 	Analysis: {}
# 	Forecast: {}
# {'typeOfLevel': 'lowCloudBottom'}
# 	Both: {}
# 	Analysis: {}
# 	Forecast: {'avg_pres': 'Time-mean pressure'}
# {'typeOfLevel': 'lowCloudLayer'}
# 	Both: {}
# 	Analysis: {}
# 	Forecast: {'tcc': 'Total Cloud Cover'}
# {'typeOfLevel': 'lowCloudTop'}
# 	Both: {}
# 	Analysis: {}
# 	Forecast: {'avg_pres': 'Time-mean pressure', 'avg_t': 'Time-mean temperature'}
# {'typeOfLevel': 'maxWind'}
# 	Both: {'gh': 'Geopotential height', 'icaht': 'ICAO Standard Atmosphere reference height', 'pres': 'Pressure', 't': 'Temperature', 'u': 'U component of wind', 'v': 'V component of wind'}
# 	Analysis: {}
# 	Forecast: {}
# {'typeOfLevel': 'meanSea'}
# 	Both: {'mslet': 'MSLP (Eta model reduction)', 'prmsl': 'Pressure reduced to MSL'}
# 	Analysis: {}
# 	Forecast: {}
# {'typeOfLevel': 'middleCloudBottom'}
# 	Both: {}
# 	Analysis: {}
# 	Forecast: {'avg_pres': 'Time-mean pressure'}
# {'typeOfLevel': 'middleCloudLayer'}
# 	Both: {}
# 	Analysis: {}
# 	Forecast: {'tcc': 'Total Cloud Cover'}
# {'typeOfLevel': 'middleCloudTop'}
# 	Both: {}
# 	Analysis: {}
# 	Forecast: {'avg_pres': 'Time-mean pressure', 'avg_t': 'Time-mean temperature'}
# {'typeOfLevel': 'nominalTop'}
# 	Both: {}
# 	Analysis: {}
# 	Forecast: {'sulwrf': 'Surface upward long-wave radiation flux', 'suswrf': 'Surface upward short-wave radiation flux'}
# {'typeOfLevel': 'planetaryBoundaryLayer'}
# 	Both: {'VRATE': 'Ventilation Rate', 'u': 'U component of wind', 'v': 'V component of wind'}
# 	Analysis: {}
# 	Forecast: {}
# {'typeOfLevel': 'potentialVorticity'}
# 	Both: {'gh': 'Geopotential height', 'pres': 'Pressure', 't': 'Temperature', 'u': 'U component of wind', 'v': 'V component of wind', 'vwsh': 'Vertical speed shear'}
# 	Analysis: {}
# 	Forecast: {}
# {'typeOfLevel': 'pressureFromGroundLayer', 'level': 3000}
# 	Both: {'q': 'Specific humidity', 'r': 'Relative humidity', 't': 'Temperature', 'u': 'U component of wind', 'v': 'V component of wind'}
# 	Analysis: {}
# 	Forecast: {}
# {'typeOfLevel': 'pressureFromGroundLayer', 'level': 6000}
# 	Both: {'q': 'Specific humidity', 'r': 'Relative humidity', 't': 'Temperature', 'u': 'U component of wind', 'v': 'V component of wind'}
# 	Analysis: {}
# 	Forecast: {}
# {'typeOfLevel': 'pressureFromGroundLayer', 'level': 9000}
# 	Both: {'q': 'Specific humidity', 'r': 'Relative humidity', 't': 'Temperature', 'u': 'U component of wind', 'v': 'V component of wind'}
# 	Analysis: {}
# 	Forecast: {}
# {'typeOfLevel': 'pressureFromGroundLayer', 'level': 12000}
# 	Both: {'q': 'Specific humidity', 'r': 'Relative humidity', 't': 'Temperature', 'u': 'U component of wind', 'v': 'V component of wind'}
# 	Analysis: {}
# 	Forecast: {}
# {'typeOfLevel': 'pressureFromGroundLayer', 'level': 15000}
# 	Both: {'q': 'Specific humidity', 'r': 'Relative humidity', 't': 'Temperature', 'u': 'U component of wind', 'v': 'V component of wind'}
# 	Analysis: {}
# 	Forecast: {}
# {'typeOfLevel': 'pressureFromGroundLayer', 'level': 18000}
# 	Both: {'cape': 'Convective available potential energy', 'cin': 'Convective inhibition', 'q': 'Specific humidity', 'r': 'Relative humidity', 't': 'Temperature', 'u': 'U component of wind', 'v': 'V component of wind'}
# 	Analysis: {}
# 	Forecast: {}
# {'typeOfLevel': 'pressureFromGroundLayer', 'level': 25500}
# 	Both: {'cape': 'Convective available potential energy', 'cin': 'Convective inhibition', 'plpl': 'Pressure of level from which parcel was lifted'}
# 	Analysis: {}
# 	Forecast: {}
# {'typeOfLevel': 'sigma'}
# 	Both: {'pt': 'Potential temperature', 'r': 'Relative humidity', 't': 'Temperature', 'u': 'U component of wind', 'v': 'V component of wind', 'w': 'Vertical velocity'}
# 	Analysis: {}
# 	Forecast: {}
# {'typeOfLevel': 'sigmaLayer'}
# 	Both: {'r': 'Relative humidity'}
# 	Analysis: {}
# 	Forecast: {}
# {'typeOfLevel': 'surface'}
# 	Both: {'SUNSD': 'Sunshine Duration', 'cape': 'Convective available potential energy', 'cin': 'Convective inhibition', 'cnwat': 'Plant canopy surface water', 'cpofp': 'Percent frozen precipitation', 'fldcp': 'Field Capacity', 'gust': 'Wind speed (gust)', 'hindex': 'Haines Index', 'landn': 'Land-sea coverage (nearest neighbor) [land=1,sea=0]', 'lftx': 'Surface lifted index', 'lftx4': 'Best (4-layer) lifted index', 'lsm': 'Land-sea mask', 'orog': 'Orography', 'sde': 'Snow depth', 'sdwe': 'Water equivalent of accumulated snow depth (deprecated)', 'siconc': 'Sea ice area fraction', 'sithick': 'Sea ice thickness', 'sp': 'Surface pressure', 't': 'Temperature', 'unknown': 'unknown', 'vis': 'Visibility', 'wilt': 'Wilting Point'}
# 	Analysis: {}
# 	Forecast: {'acpcp': 'Convective precipitation (water)', 'avg_al': 'Time-mean forecast albedo', 'avg_ishf': 'Time-mean surface sensible heat flux', 'avg_slhtf': 'Time-mean surface latent heat flux', 'avg_utaua': 'Time-mean U-component of atmospheric surface momentum flux', 'avg_vtaua': 'Time-mean V-component of atmospheric surface momentum flux', 'cduvb': 'Clear sky UV-B downward solar flux', 'cfrzr': 'Categorical freezing rain', 'cicep': 'Categorical ice pellets', 'cpr': 'Convective precipitation rate', 'crain': 'Categorical rain', 'csnow': 'Categorical snow', 'duvb': 'UV-B downward solar flux', 'gflux': 'Ground heat flux', 'iegwss': 'Instantaneous eastward gravity wave surface stress', 'ingwss': 'Instantaneous northward gravity wave surface stress', 'prate': 'Precipitation rate', 'sdlwrf': 'Surface downward long-wave radiation flux', 'sdswrf': 'Surface downward short-wave radiation flux', 'sulwrf': 'Surface upward long-wave radiation flux', 'suswrf': 'Surface upward short-wave radiation flux', 'tp': 'Total Precipitation', 'watr': 'Water runoff'}
# {'typeOfLevel': 'tropopause'}
# 	Both: {'gh': 'Geopotential height', 'icaht': 'ICAO Standard Atmosphere reference height', 't': 'Temperature', 'trpp': 'Tropopause pressure', 'u': 'U component of wind', 'v': 'V component of wind', 'vwsh': 'Vertical speed shear'}
# 	Analysis: {}
# 	Forecast: {}

# %%
ds = xr.open_dataset(
    "grib-store/hrrr.t00z.wrfprsf06.grib2",
    engine="cfgrib",
    filter_by_keys={
        "typeOfLevel": "meanSea",
        #"level": level,
        #"paramId": 131,
        #"stepType": stepType,
    },
    decode_timedelta=True,
)

# %%
ds.time.values
# Out:
# np.datetime64('2018-04-25T00:00:00.000000000')

# %% [markdown]
# ## Here's what we got

# %%
typeOfLevels = [
    "atmosphere",
    "depthBelowLandLayer",
    "heightAboveGround",
    "highCloudLayer",
    "isobaricInhPa",
    "lowCloudLayer",
    "meanSea",
    "middleCloudLayer",
    "surface",
]

# %%
isobaric_variables = {
    "gh": 156,
	"t": 130,
	"r": 157,
	"w": 135,
	"u": 131,
	"v": 132,
	"absv": 3041,
	"clwmr": 260018,
	"ICSEV": 7001293,
	"o3mr": 260131,
	"q": 133,
    "wavh5": 260080,
}

# %%
def read_fhr(fhr, fbk):
    t0 = time.time()
    hr = 0
    dslist = []
    a = xr.open_dataset(
        f"grib-store/gfs.0p25.20180425{hr:02d}.f{fhr:03d}.grib2",
        engine="cfgrib",
        decode_timedelta=True,
        filter_by_keys=fbk,
    )
    if "unknown" in a:
        a = a.drop_vars("unknown")
    b = xr.open_dataset(
        f"grib-store/gfs.0p25b.20180425{hr:02d}.f{fhr:03d}.grib2",
        engine="cfgrib",
        decode_timedelta=True,
        filter_by_keys=fbk,
    )
    if "unknown" in b:
        b = b.drop_vars("unknown")
    xds = xr.merge([a,b])
    tf = time.time()
    print(f"{fbk} in {tf-t0:.1f} sec")

    # figure out variables
    avars = sorted(a.data_vars)
    bvars = sorted(b.data_vars)
    allvars = sorted(xds.data_vars)
    for key in allvars:
        file_suffixes = []
        if key in avars:
            file_suffixes.append("")
        if key in bvars:
            file_suffixes.append("b")
        xds[key].attrs["file_suffixes"] = file_suffixes
    return xds

# %%
# %%time
hr = 0

fds = {}
for fhr in [0, 6]:
    vlist = []
    dslist = []
    for typeOfLevel in typeOfLevels:
        fbk = {"typeOfLevel": typeOfLevel}
        if typeOfLevel == "heightAboveGround":
            for level in levels[typeOfLevel]:
                fbk["level"] = level
                xds = read_fhr(fhr, fbk)
                if len(xds) > 0:
                    xds = xds.drop_vars("heightAboveGround")
                
                    for key in ["aptmp", "tmax", "tmin", "pres", "t", "q", "u", "v", "pt", "refd"]:
                        if key in xds:
                            new = f"{key}{level}"
                            xds = xds.rename({key: new})
                            xds[new].attrs["long_name"] = f"{level} metre " + xds[new].attrs["long_name"]
                            xds[new].attrs["original_name"] = key
                    for key in xds.data_vars:
                        xds[key].attrs["GRIB_level"] = level
                    dslist.append(xds) 
        elif typeOfLevel == "isobaricInhPa":
            for varname, paramId in isobaric_variables.items():
                fbk["paramId"] = paramId
                xds = read_fhr(fhr, fbk)
                if len(xds) > 0:
                    if len(xds.dims) < 3:
                        vv = xds["isobaricInhPa"].values
                        xds = xds.expand_dims({"isobaricInhPa": [vv]})
                    dslist.append(xds)
                
    
        elif typeOfLevel == "surface":
            xds = read_fhr(fhr, fbk)
            xds = xds.drop_vars(typeOfLevel)
            if len(xds) > 0:
                if "t" in xds:
                    xds = xds.rename({"t": "t_surface"})
                    xds["t_surface"].attrs["original_name"] = "t"
                    
                dslist.append(xds)
        else:
            xds = read_fhr(fhr, fbk)
            if len(xds) > 0:
                xds = xds.drop_vars(typeOfLevel)
                if len(xds) > 0:
                    if typeOfLevel in ("lowCloudLayer", "middleCloudLayer", "highCloudLayer"):
                        full = typeOfLevel.replace("CloudLayer", "") # l, m, or h
                        new = f"{full[0]}cc"
                        xds = xds.rename({"tcc": new})
                        for kk in ["long_name", "GRIB_name"]:
                            xds[new].attrs[kk] = xds[new].attrs[kk].replace("Total", full.capitalize())
                        for kk in ["GRIB_cfVarName", "GRIB_shortName"]:
                            xds[new].attrs[kk] = new
                        xds[new].attrs["original_name"] = "tcc"
                        
                    dslist.append(xds)
    fds[fhr] = xr.merge(dslist)
# Out:
# {'typeOfLevel': 'atmosphere'} in 0.0 sec
# {'typeOfLevel': 'depthBelowLandLayer'} in 0.0 sec
# {'typeOfLevel': 'heightAboveGround', 'level': 2} in 0.0 sec
# {'typeOfLevel': 'heightAboveGround', 'level': 10} in 0.0 sec
# {'typeOfLevel': 'heightAboveGround', 'level': 80} in 0.0 sec
# {'typeOfLevel': 'heightAboveGround', 'level': 100} in 0.0 sec
# {'typeOfLevel': 'heightAboveGround', 'level': 3000} in 0.0 sec
# {'typeOfLevel': 'heightAboveGround', 'level': 6000} in 0.0 sec
# {'typeOfLevel': 'highCloudLayer'} in 0.0 sec
# {'typeOfLevel': 'isobaricInhPa', 'paramId': 156} in 2.2 sec
# {'typeOfLevel': 'isobaricInhPa', 'paramId': 130} in 2.1 sec
# {'typeOfLevel': 'isobaricInhPa', 'paramId': 157} in 2.1 sec
# {'typeOfLevel': 'isobaricInhPa', 'paramId': 135} in 1.7 sec
# {'typeOfLevel': 'isobaricInhPa', 'paramId': 131} in 2.1 sec
# {'typeOfLevel': 'isobaricInhPa', 'paramId': 132} in 2.1 sec
# {'typeOfLevel': 'isobaricInhPa', 'paramId': 3041} in 2.0 sec
# {'typeOfLevel': 'isobaricInhPa', 'paramId': 260018} in 1.8 sec
# {'typeOfLevel': 'isobaricInhPa', 'paramId': 7001293} in 0.0 sec
# {'typeOfLevel': 'isobaricInhPa', 'paramId': 260131} in 0.8 sec
# {'typeOfLevel': 'isobaricInhPa', 'paramId': 133} in 0.0 sec
# {'typeOfLevel': 'isobaricInhPa', 'paramId': 260080} in 0.0 sec
# {'typeOfLevel': 'lowCloudLayer'} in 0.0 sec
# {'typeOfLevel': 'meanSea'} in 0.0 sec
# {'typeOfLevel': 'middleCloudLayer'} in 0.0 sec
# {'typeOfLevel': 'surface'} in 0.1 sec
# {'typeOfLevel': 'atmosphere'} in 0.0 sec
# {'typeOfLevel': 'depthBelowLandLayer'} in 0.0 sec
# {'typeOfLevel': 'heightAboveGround', 'level': 2} in 0.0 sec
# {'typeOfLevel': 'heightAboveGround', 'level': 10} in 0.0 sec
# {'typeOfLevel': 'heightAboveGround', 'level': 80} in 0.0 sec
# {'typeOfLevel': 'heightAboveGround', 'level': 100} in 0.0 sec
# {'typeOfLevel': 'heightAboveGround', 'level': 3000} in 0.0 sec
# {'typeOfLevel': 'heightAboveGround', 'level': 6000} in 0.0 sec
# {'typeOfLevel': 'highCloudLayer'} in 0.0 sec
# {'typeOfLevel': 'isobaricInhPa', 'paramId': 156} in 2.3 sec
# {'typeOfLevel': 'isobaricInhPa', 'paramId': 130} in 2.7 sec
# {'typeOfLevel': 'isobaricInhPa', 'paramId': 157} in 2.5 sec
# {'typeOfLevel': 'isobaricInhPa', 'paramId': 135} in 1.8 sec
# {'typeOfLevel': 'isobaricInhPa', 'paramId': 131} in 3.0 sec
# {'typeOfLevel': 'isobaricInhPa', 'paramId': 132} in 2.5 sec
# {'typeOfLevel': 'isobaricInhPa', 'paramId': 3041} in 2.1 sec
# {'typeOfLevel': 'isobaricInhPa', 'paramId': 260018} in 1.7 sec
# {'typeOfLevel': 'isobaricInhPa', 'paramId': 7001293} in 0.0 sec
# {'typeOfLevel': 'isobaricInhPa', 'paramId': 260131} in 0.9 sec
# {'typeOfLevel': 'isobaricInhPa', 'paramId': 133} in 0.0 sec
# {'typeOfLevel': 'isobaricInhPa', 'paramId': 260080} in 0.0 sec
# {'typeOfLevel': 'lowCloudLayer'} in 0.0 sec
# {'typeOfLevel': 'meanSea'} in 0.0 sec
# {'typeOfLevel': 'middleCloudLayer'} in 0.0 sec
# {'typeOfLevel': 'surface'} in 0.2 sec
# CPU times: user 32 s, sys: 9.42 s, total: 41.4 s
# Wall time: 44 s

# %%
allvars = set(fds[0].data_vars).union(fds[6].data_vars)
both = set(fds[0].data_vars).intersection(fds[6].data_vars)
analysis = set(fds[0].data_vars) - set(fds[6].data_vars)
forecast = set(fds[6].data_vars) - set(fds[0].data_vars)

# %%
print(sorted(allvars))
# Out:
# ['ICSEV', 'SUNSD', 'absv', 'acpcp', 'aptmp2', 'avg_al', 'avg_ishf', 'avg_slhtf', 'avg_utaua', 'avg_vtaua', 'cape', 'cduvb', 'cfrzr', 'cicep', 'cin', 'clwmr', 'cnwat', 'cpofp', 'cpr', 'crain', 'csnow', 'd2m', 'duvb', 'fldcp', 'gflux', 'gh', 'gust', 'hcc', 'hindex', 'iegwss', 'ingwss', 'landn', 'lcc', 'lftx', 'lftx4', 'lsm', 'mcc', 'mslet', 'o3mr', 'orog', 'prate', 'pres80', 'prmsl', 'q', 'q80', 'r', 'r2', 'sde', 'sdlwrf', 'sdswrf', 'sdwe', 'sh2', 'siconc', 'sithick', 'soill', 'soilw', 'sp', 'st', 'sulwrf', 'suswrf', 't', 't100', 't2m', 't80', 't_surface', 'tcc', 'tmax2', 'tmin2', 'tp', 'u', 'u10', 'u100', 'u80', 'v', 'v10', 'v100', 'v80', 'vis', 'w', 'watr', 'wavh5', 'wilt']

# %%
print(sorted(both))
# Out:
# ['SUNSD', 'absv', 'aptmp2', 'cape', 'cin', 'clwmr', 'cnwat', 'cpofp', 'd2m', 'fldcp', 'gh', 'gust', 'hindex', 'landn', 'lftx', 'lftx4', 'lsm', 'mslet', 'o3mr', 'orog', 'pres80', 'prmsl', 'q', 'q80', 'r', 'r2', 'sde', 'sdwe', 'sh2', 'siconc', 'sithick', 'soill', 'soilw', 'sp', 'st', 't', 't100', 't2m', 't80', 't_surface', 'u', 'u10', 'u100', 'u80', 'v', 'v10', 'v100', 'v80', 'vis', 'w', 'wavh5', 'wilt']

# %%
print(sorted(analysis))
# Out:
# []

# %%
print(sorted(forecast))
# Out:
# ['ICSEV', 'acpcp', 'avg_al', 'avg_ishf', 'avg_slhtf', 'avg_utaua', 'avg_vtaua', 'cduvb', 'cfrzr', 'cicep', 'cpr', 'crain', 'csnow', 'duvb', 'gflux', 'hcc', 'iegwss', 'ingwss', 'lcc', 'mcc', 'prate', 'sdlwrf', 'sdswrf', 'sulwrf', 'suswrf', 'tcc', 'tmax2', 'tmin2', 'tp', 'watr']

# %% [markdown]
# ### Make the reference yaml

# %%
ds = fds[6]

# %%
bigdict = {}
for varname in sorted(allvars):
    bigdict[varname] = {
        "filter_by_keys": {
            "typeOfLevel": ds[varname].GRIB_typeOfLevel,
            "paramId": ds[varname].GRIB_paramId,
        },
        "file_suffixes": ds[varname].file_suffixes,
        "long_name": ds[varname].long_name,
        "forecast_only": varname in forecast,
    }
    if ds[varname].GRIB_typeOfLevel == "heightAboveGround":
        bigdict[varname]["filter_by_keys"]["level"] = ds[varname].attrs["GRIB_level"]
    if "original_name" in ds[varname].attrs:
        bigdict[varname]["original_name"] = ds[varname].original_name

# %%
smallerdict = {k:v for k,v in bigdict.items() if k in ["lsm", "orog", "sp", "u10", "v10", "t2m", "sh2", "d2m", "gh", "u", "v", "w", "t", "q"]}

# %%
import yaml

# %%
with open("reference.gfs.yaml", "w") as f:
    yaml.dump(smallerdict, f)

# %%
bigdict
# Out:
# {'ICSEV': {'filter_by_keys': {'typeOfLevel': 'isobaricInhPa',
#    'paramId': 7001293},
#   'file_suffixes': [''],
#   'long_name': 'Icing severity',
#   'forecast_only': True},
#  'SUNSD': {'filter_by_keys': {'typeOfLevel': 'surface', 'paramId': 7001292},
#   'file_suffixes': [''],
#   'long_name': 'Sunshine Duration',
#   'forecast_only': False},
#  'absv': {'filter_by_keys': {'typeOfLevel': 'isobaricInhPa', 'paramId': 3041},
#   'file_suffixes': ['', 'b'],
#   'long_name': 'Absolute vorticity',
#   'forecast_only': False},
#  'acpcp': {'filter_by_keys': {'typeOfLevel': 'surface', 'paramId': 3063},
#   'file_suffixes': [''],
#   'long_name': 'Convective precipitation (water)',
#   'forecast_only': True},
#  'aptmp2': {'filter_by_keys': {'typeOfLevel': 'heightAboveGround',
#    'paramId': 260255,
#    'level': 2},
#   'file_suffixes': [''],
#   'long_name': '2 metre Apparent temperature',
#   'forecast_only': False,
#   'original_name': 'aptmp'},
#  'avg_al': {'filter_by_keys': {'typeOfLevel': 'surface', 'paramId': 235263},
#   'file_suffixes': [''],
#   'long_name': 'Time-mean forecast albedo',
#   'forecast_only': True},
#  'avg_ishf': {'filter_by_keys': {'typeOfLevel': 'surface', 'paramId': 235033},
#   'file_suffixes': [''],
#   'long_name': 'Time-mean surface sensible heat flux',
#   'forecast_only': True},
#  'avg_slhtf': {'filter_by_keys': {'typeOfLevel': 'surface', 'paramId': 235034},
#   'file_suffixes': [''],
#   'long_name': 'Time-mean surface latent heat flux',
#   'forecast_only': True},
#  'avg_utaua': {'filter_by_keys': {'typeOfLevel': 'surface', 'paramId': 141101},
#   'file_suffixes': [''],
#   'long_name': 'Time-mean U-component of atmospheric surface momentum flux',
#   'forecast_only': True},
#  'avg_vtaua': {'filter_by_keys': {'typeOfLevel': 'surface', 'paramId': 141102},
#   'file_suffixes': [''],
#   'long_name': 'Time-mean V-component of atmospheric surface momentum flux',
#   'forecast_only': True},
#  'cape': {'filter_by_keys': {'typeOfLevel': 'surface', 'paramId': 59},
#   'file_suffixes': [''],
#   'long_name': 'Convective available potential energy',
#   'forecast_only': False},
#  'cduvb': {'filter_by_keys': {'typeOfLevel': 'surface', 'paramId': 260341},
#   'file_suffixes': ['b'],
#   'long_name': 'Clear sky UV-B downward solar flux',
#   'forecast_only': True},
#  'cfrzr': {'filter_by_keys': {'typeOfLevel': 'surface', 'paramId': 260030},
#   'file_suffixes': [''],
#   'long_name': 'Categorical freezing rain',
#   'forecast_only': True},
#  'cicep': {'filter_by_keys': {'typeOfLevel': 'surface', 'paramId': 260031},
#   'file_suffixes': [''],
#   'long_name': 'Categorical ice pellets',
#   'forecast_only': True},
#  'cin': {'filter_by_keys': {'typeOfLevel': 'surface', 'paramId': 228001},
#   'file_suffixes': [''],
#   'long_name': 'Convective inhibition',
#   'forecast_only': False},
#  'clwmr': {'filter_by_keys': {'typeOfLevel': 'isobaricInhPa',
#    'paramId': 260018},
#   'file_suffixes': ['', 'b'],
#   'long_name': 'Cloud mixing ratio',
#   'forecast_only': False},
#  'cnwat': {'filter_by_keys': {'typeOfLevel': 'surface', 'paramId': 260189},
#   'file_suffixes': ['b'],
#   'long_name': 'Plant canopy surface water',
#   'forecast_only': False},
#  'cpofp': {'filter_by_keys': {'typeOfLevel': 'surface', 'paramId': 260035},
#   'file_suffixes': [''],
#   'long_name': 'Percent frozen precipitation',
#   'forecast_only': False},
#  'cpr': {'filter_by_keys': {'typeOfLevel': 'surface', 'paramId': 260033},
#   'file_suffixes': [''],
#   'long_name': 'Convective precipitation rate',
#   'forecast_only': True},
#  'crain': {'filter_by_keys': {'typeOfLevel': 'surface', 'paramId': 260029},
#   'file_suffixes': [''],
#   'long_name': 'Categorical rain',
#   'forecast_only': True},
#  'csnow': {'filter_by_keys': {'typeOfLevel': 'surface', 'paramId': 260032},
#   'file_suffixes': [''],
#   'long_name': 'Categorical snow',
#   'forecast_only': True},
#  'd2m': {'filter_by_keys': {'typeOfLevel': 'heightAboveGround',
#    'paramId': 168,
#    'level': 2},
#   'file_suffixes': [''],
#   'long_name': '2 metre dewpoint temperature',
#   'forecast_only': False},
#  'duvb': {'filter_by_keys': {'typeOfLevel': 'surface', 'paramId': 260340},
#   'file_suffixes': ['b'],
#   'long_name': 'UV-B downward solar flux',
#   'forecast_only': True},
#  'fldcp': {'filter_by_keys': {'typeOfLevel': 'surface', 'paramId': 260483},
#   'file_suffixes': [''],
#   'long_name': 'Field Capacity',
#   'forecast_only': False},
#  'gflux': {'filter_by_keys': {'typeOfLevel': 'surface', 'paramId': 260186},
#   'file_suffixes': [''],
#   'long_name': 'Ground heat flux',
#   'forecast_only': True},
#  'gh': {'filter_by_keys': {'typeOfLevel': 'isobaricInhPa', 'paramId': 156},
#   'file_suffixes': ['', 'b'],
#   'long_name': 'Geopotential height',
#   'forecast_only': False},
#  'gust': {'filter_by_keys': {'typeOfLevel': 'surface', 'paramId': 260065},
#   'file_suffixes': [''],
#   'long_name': 'Wind speed (gust)',
#   'forecast_only': False},
#  'hcc': {'filter_by_keys': {'typeOfLevel': 'highCloudLayer',
#    'paramId': 228164},
#   'file_suffixes': [''],
#   'long_name': 'High Cloud Cover',
#   'forecast_only': True,
#   'original_name': 'tcc'},
#  'hindex': {'filter_by_keys': {'typeOfLevel': 'surface', 'paramId': 260256},
#   'file_suffixes': [''],
#   'long_name': 'Haines Index',
#   'forecast_only': False},
#  'iegwss': {'filter_by_keys': {'typeOfLevel': 'surface', 'paramId': 260081},
#   'file_suffixes': [''],
#   'long_name': 'Instantaneous eastward gravity wave surface stress',
#   'forecast_only': True},
#  'ingwss': {'filter_by_keys': {'typeOfLevel': 'surface', 'paramId': 260082},
#   'file_suffixes': [''],
#   'long_name': 'Instantaneous northward gravity wave surface stress',
#   'forecast_only': True},
#  'landn': {'filter_by_keys': {'typeOfLevel': 'surface', 'paramId': 260459},
#   'file_suffixes': [''],
#   'long_name': 'Land-sea coverage (nearest neighbor) [land=1,sea=0]',
#   'forecast_only': False},
#  'lcc': {'filter_by_keys': {'typeOfLevel': 'lowCloudLayer', 'paramId': 228164},
#   'file_suffixes': [''],
#   'long_name': 'Low Cloud Cover',
#   'forecast_only': True,
#   'original_name': 'tcc'},
#  'lftx': {'filter_by_keys': {'typeOfLevel': 'surface', 'paramId': 260127},
#   'file_suffixes': [''],
#   'long_name': 'Surface lifted index',
#   'forecast_only': False},
#  'lftx4': {'filter_by_keys': {'typeOfLevel': 'surface', 'paramId': 260128},
#   'file_suffixes': [''],
#   'long_name': 'Best (4-layer) lifted index',
#   'forecast_only': False},
#  'lsm': {'filter_by_keys': {'typeOfLevel': 'surface', 'paramId': 172},
#   'file_suffixes': [''],
#   'long_name': 'Land-sea mask',
#   'forecast_only': False},
#  'mcc': {'filter_by_keys': {'typeOfLevel': 'middleCloudLayer',
#    'paramId': 228164},
#   'file_suffixes': [''],
#   'long_name': 'Middle Cloud Cover',
#   'forecast_only': True,
#   'original_name': 'tcc'},
#  'mslet': {'filter_by_keys': {'typeOfLevel': 'meanSea', 'paramId': 260317},
#   'file_suffixes': [''],
#   'long_name': 'MSLP (Eta model reduction)',
#   'forecast_only': False},
#  'o3mr': {'filter_by_keys': {'typeOfLevel': 'isobaricInhPa',
#    'paramId': 260131},
#   'file_suffixes': ['', 'b'],
#   'long_name': 'Ozone mixing ratio',
#   'forecast_only': False},
#  'orog': {'filter_by_keys': {'typeOfLevel': 'surface', 'paramId': 228002},
#   'file_suffixes': [''],
#   'long_name': 'Orography',
#   'forecast_only': False},
#  'prate': {'filter_by_keys': {'typeOfLevel': 'surface', 'paramId': 3059},
#   'file_suffixes': [''],
#   'long_name': 'Precipitation rate',
#   'forecast_only': True},
#  'pres80': {'filter_by_keys': {'typeOfLevel': 'heightAboveGround',
#    'paramId': 54,
#    'level': 80},
#   'file_suffixes': [''],
#   'long_name': '80 metre Pressure',
#   'forecast_only': False,
#   'original_name': 'pres'},
#  'prmsl': {'filter_by_keys': {'typeOfLevel': 'meanSea', 'paramId': 260074},
#   'file_suffixes': [''],
#   'long_name': 'Pressure reduced to MSL',
#   'forecast_only': False},
#  'q': {'filter_by_keys': {'typeOfLevel': 'isobaricInhPa', 'paramId': 133},
#   'file_suffixes': ['b'],
#   'long_name': 'Specific humidity',
#   'forecast_only': False},
#  'q80': {'filter_by_keys': {'typeOfLevel': 'heightAboveGround',
#    'paramId': 133,
#    'level': 80},
#   'file_suffixes': [''],
#   'long_name': '80 metre Specific humidity',
#   'forecast_only': False,
#   'original_name': 'q'},
#  'r': {'filter_by_keys': {'typeOfLevel': 'isobaricInhPa', 'paramId': 157},
#   'file_suffixes': ['', 'b'],
#   'long_name': 'Relative humidity',
#   'forecast_only': False},
#  'r2': {'filter_by_keys': {'typeOfLevel': 'heightAboveGround',
#    'paramId': 260242,
#    'level': 2},
#   'file_suffixes': [''],
#   'long_name': '2 metre relative humidity',
#   'forecast_only': False},
#  'sde': {'filter_by_keys': {'typeOfLevel': 'surface', 'paramId': 3066},
#   'file_suffixes': [''],
#   'long_name': 'Snow depth',
#   'forecast_only': False},
#  'sdlwrf': {'filter_by_keys': {'typeOfLevel': 'surface', 'paramId': 260097},
#   'file_suffixes': [''],
#   'long_name': 'Surface downward long-wave radiation flux',
#   'forecast_only': True},
#  'sdswrf': {'filter_by_keys': {'typeOfLevel': 'surface', 'paramId': 260087},
#   'file_suffixes': [''],
#   'long_name': 'Surface downward short-wave radiation flux',
#   'forecast_only': True},
#  'sdwe': {'filter_by_keys': {'typeOfLevel': 'surface', 'paramId': 260056},
#   'file_suffixes': [''],
#   'long_name': 'Water equivalent of accumulated snow depth (deprecated)',
#   'forecast_only': False},
#  'sh2': {'filter_by_keys': {'typeOfLevel': 'heightAboveGround',
#    'paramId': 174096,
#    'level': 2},
#   'file_suffixes': [''],
#   'long_name': '2 metre specific humidity',
#   'forecast_only': False},
#  'siconc': {'filter_by_keys': {'typeOfLevel': 'surface', 'paramId': 31},
#   'file_suffixes': [''],
#   'long_name': 'Sea ice area fraction',
#   'forecast_only': False},
#  'sithick': {'filter_by_keys': {'typeOfLevel': 'surface', 'paramId': 262000},
#   'file_suffixes': ['b'],
#   'long_name': 'Sea ice thickness',
#   'forecast_only': False},
#  'soill': {'filter_by_keys': {'typeOfLevel': 'depthBelowLandLayer',
#    'paramId': 260205},
#   'file_suffixes': ['b'],
#   'long_name': 'Liquid volumetric soil moisture (non-frozen)',
#   'forecast_only': False},
#  'soilw': {'filter_by_keys': {'typeOfLevel': 'depthBelowLandLayer',
#    'paramId': 260185},
#   'file_suffixes': [''],
#   'long_name': 'Volumetric soil moisture content',
#   'forecast_only': False},
#  'sp': {'filter_by_keys': {'typeOfLevel': 'surface', 'paramId': 134},
#   'file_suffixes': [''],
#   'long_name': 'Surface pressure',
#   'forecast_only': False},
#  'st': {'filter_by_keys': {'typeOfLevel': 'depthBelowLandLayer',
#    'paramId': 228139},
#   'file_suffixes': [''],
#   'long_name': 'Soil temperature',
#   'forecast_only': False},
#  'sulwrf': {'filter_by_keys': {'typeOfLevel': 'surface', 'paramId': 260098},
#   'file_suffixes': [''],
#   'long_name': 'Surface upward long-wave radiation flux',
#   'forecast_only': True},
#  'suswrf': {'filter_by_keys': {'typeOfLevel': 'surface', 'paramId': 260088},
#   'file_suffixes': [''],
#   'long_name': 'Surface upward short-wave radiation flux',
#   'forecast_only': True},
#  't': {'filter_by_keys': {'typeOfLevel': 'isobaricInhPa', 'paramId': 130},
#   'file_suffixes': ['', 'b'],
#   'long_name': 'Temperature',
#   'forecast_only': False},
#  't100': {'filter_by_keys': {'typeOfLevel': 'heightAboveGround',
#    'paramId': 130,
#    'level': 100},
#   'file_suffixes': [''],
#   'long_name': '100 metre Temperature',
#   'forecast_only': False,
#   'original_name': 't'},
#  't2m': {'filter_by_keys': {'typeOfLevel': 'heightAboveGround',
#    'paramId': 167,
#    'level': 2},
#   'file_suffixes': [''],
#   'long_name': '2 metre temperature',
#   'forecast_only': False},
#  't80': {'filter_by_keys': {'typeOfLevel': 'heightAboveGround',
#    'paramId': 130,
#    'level': 80},
#   'file_suffixes': [''],
#   'long_name': '80 metre Temperature',
#   'forecast_only': False,
#   'original_name': 't'},
#  't_surface': {'filter_by_keys': {'typeOfLevel': 'surface', 'paramId': 130},
#   'file_suffixes': [''],
#   'long_name': 'Temperature',
#   'forecast_only': False,
#   'original_name': 't'},
#  'tcc': {'filter_by_keys': {'typeOfLevel': 'atmosphere', 'paramId': 228164},
#   'file_suffixes': [''],
#   'long_name': 'Total Cloud Cover',
#   'forecast_only': True},
#  'tmax2': {'filter_by_keys': {'typeOfLevel': 'heightAboveGround',
#    'paramId': 3015,
#    'level': 2},
#   'file_suffixes': [''],
#   'long_name': '2 metre Maximum temperature',
#   'forecast_only': True,
#   'original_name': 'tmax'},
#  'tmin2': {'filter_by_keys': {'typeOfLevel': 'heightAboveGround',
#    'paramId': 3016,
#    'level': 2},
#   'file_suffixes': [''],
#   'long_name': '2 metre Minimum temperature',
#   'forecast_only': True,
#   'original_name': 'tmin'},
#  'tp': {'filter_by_keys': {'typeOfLevel': 'surface', 'paramId': 228228},
#   'file_suffixes': [''],
#   'long_name': 'Total Precipitation',
#   'forecast_only': True},
#  'u': {'filter_by_keys': {'typeOfLevel': 'isobaricInhPa', 'paramId': 131},
#   'file_suffixes': ['', 'b'],
#   'long_name': 'U component of wind',
#   'forecast_only': False},
#  'u10': {'filter_by_keys': {'typeOfLevel': 'heightAboveGround',
#    'paramId': 165,
#    'level': 10},
#   'file_suffixes': [''],
#   'long_name': '10 metre U wind component',
#   'forecast_only': False},
#  'u100': {'filter_by_keys': {'typeOfLevel': 'heightAboveGround',
#    'paramId': 228246,
#    'level': 100},
#   'file_suffixes': [''],
#   'long_name': '100 metre U wind component',
#   'forecast_only': False},
#  'u80': {'filter_by_keys': {'typeOfLevel': 'heightAboveGround',
#    'paramId': 131,
#    'level': 80},
#   'file_suffixes': [''],
#   'long_name': '80 metre U component of wind',
#   'forecast_only': False,
#   'original_name': 'u'},
#  'v': {'filter_by_keys': {'typeOfLevel': 'isobaricInhPa', 'paramId': 132},
#   'file_suffixes': ['', 'b'],
#   'long_name': 'V component of wind',
#   'forecast_only': False},
#  'v10': {'filter_by_keys': {'typeOfLevel': 'heightAboveGround',
#    'paramId': 166,
#    'level': 10},
#   'file_suffixes': [''],
#   'long_name': '10 metre V wind component',
#   'forecast_only': False},
#  'v100': {'filter_by_keys': {'typeOfLevel': 'heightAboveGround',
#    'paramId': 228247,
#    'level': 100},
#   'file_suffixes': [''],
#   'long_name': '100 metre V wind component',
#   'forecast_only': False},
#  'v80': {'filter_by_keys': {'typeOfLevel': 'heightAboveGround',
#    'paramId': 132,
#    'level': 80},
#   'file_suffixes': [''],
#   'long_name': '80 metre V component of wind',
#   'forecast_only': False,
#   'original_name': 'v'},
#  'vis': {'filter_by_keys': {'typeOfLevel': 'surface', 'paramId': 3020},
#   'file_suffixes': [''],
#   'long_name': 'Visibility',
#   'forecast_only': False},
#  'w': {'filter_by_keys': {'typeOfLevel': 'isobaricInhPa', 'paramId': 135},
#   'file_suffixes': ['', 'b'],
#   'long_name': 'Vertical velocity',
#   'forecast_only': False},
#  'watr': {'filter_by_keys': {'typeOfLevel': 'surface', 'paramId': 260181},
#   'file_suffixes': [''],
#   'long_name': 'Water runoff',
#   'forecast_only': True},
#  'wavh5': {'filter_by_keys': {'typeOfLevel': 'isobaricInhPa',
#    'paramId': 260080},
#   'file_suffixes': [''],
#   'long_name': '5-wave geopotential height',
#   'forecast_only': False},
#  'wilt': {'filter_by_keys': {'typeOfLevel': 'surface', 'paramId': 260442},
#   'file_suffixes': [''],
#   'long_name': 'Wilting Point',
#   'forecast_only': False}}

# %%
for key in sorted(ds.data_vars):
    print(f"{key}: {ds[key].long_name}")
# Out:
# SUNSD: Sunshine Duration
# acpcp: Convective precipitation (water)
# aptmp2: 2 metre Apparent temperature
# avg_al: Time-mean forecast albedo
# avg_ishf: Time-mean surface sensible heat flux
# avg_slhtf: Time-mean surface latent heat flux
# avg_utaua: Time-mean U-component of atmospheric surface momentum flux
# avg_vtaua: Time-mean V-component of atmospheric surface momentum flux
# cape: Convective available potential energy
# cduvb: Clear sky UV-B downward solar flux
# cfrzr: Categorical freezing rain
# cicep: Categorical ice pellets
# cin: Convective inhibition
# cnwat: Plant canopy surface water
# cpofp: Percent frozen precipitation
# cpr: Convective precipitation rate
# crain: Categorical rain
# csnow: Categorical snow
# d2m: 2 metre dewpoint temperature
# duvb: UV-B downward solar flux
# fldcp: Field Capacity
# gflux: Ground heat flux
# gh: Geopotential height
# gust: Wind speed (gust)
# hcc: High Cloud Cover
# hindex: Haines Index
# iegwss: Instantaneous eastward gravity wave surface stress
# ingwss: Instantaneous northward gravity wave surface stress
# landn: Land-sea coverage (nearest neighbor) [land=1,sea=0]
# lcc: Low Cloud Cover
# lftx: Surface lifted index
# lftx4: Best (4-layer) lifted index
# lsm: Land-sea mask
# mcc: Middle Cloud Cover
# mslet: MSLP (Eta model reduction)
# orog: Orography
# prate: Precipitation rate
# pres80: 80 metre Pressure
# prmsl: Pressure reduced to MSL
# q: Specific humidity
# q80: 80 metre Specific humidity
# r2: 2 metre relative humidity
# sde: Snow depth
# sdlwrf: Surface downward long-wave radiation flux
# sdswrf: Surface downward short-wave radiation flux
# sdwe: Water equivalent of accumulated snow depth (deprecated)
# sh2: 2 metre specific humidity
# siconc: Sea ice area fraction
# sithick: Sea ice thickness
# soill: Liquid volumetric soil moisture (non-frozen)
# soilw: Volumetric soil moisture content
# sp: Surface pressure
# st: Soil temperature
# sulwrf: Surface upward long-wave radiation flux
# suswrf: Surface upward short-wave radiation flux
# t: Temperature
# t100: 100 metre Temperature
# t2m: 2 metre temperature
# t80: 80 metre Temperature
# t_surface: Temperature
# tcc: Total Cloud Cover
# tmax2: 2 metre Maximum temperature
# tmin2: 2 metre Minimum temperature
# tp: Total Precipitation
# u: U component of wind
# u10: 10 metre U wind component
# u100: 100 metre U wind component
# u80: 80 metre U component of wind
# v: V component of wind
# v10: 10 metre V wind component
# v100: 100 metre V wind component
# v80: 80 metre V component of wind
# vis: Visibility
# w: Vertical velocity
# watr: Water runoff
# wilt: Wilting Point

# %%
fds[6].tcc
# Out:
# <xarray.DataArray 'tcc' (latitude: 721, longitude: 1440)> Size: 4MB
# [1038240 values with dtype=float32]
# Coordinates:
#     time        datetime64[ns] 8B 2018-04-25
#     step        timedelta64[ns] 8B 06:00:00
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     valid_time  datetime64[ns] 8B 2018-04-25T06:00:00
# Attributes: (12/31)
#     GRIB_paramId:                             228164
#     GRIB_dataType:                            fc
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         atmosphere
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            avg
#     ...                                       ...
#     GRIB_shortName:                           tcc
#     GRIB_units:                               %
#     long_name:                                Total Cloud Cover
#     units:                                    %
#     standard_name:                            unknown
#     file_suffixes:                            ['']

# %%
(ds.landn-ds.lsm).plot()

# %%
ds.prmsl
# Out:
# <xarray.DataArray 'mslet' (latitude: 721, longitude: 1440)> Size: 4MB
# [1038240 values with dtype=float32]
# Coordinates:
#     time        datetime64[ns] 8B 2018-04-25
#     step        timedelta64[ns] 8B 06:00:00
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     valid_time  datetime64[ns] 8B 2018-04-25T06:00:00
# Attributes: (12/30)
#     GRIB_paramId:                             260317
#     GRIB_dataType:                            fc
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         meanSea
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_name:                                MSLP (Eta model reduction)
#     GRIB_shortName:                           mslet
#     GRIB_units:                               Pa
#     long_name:                                MSLP (Eta model reduction)
#     units:                                    Pa
#     standard_name:                            unknown

# %%
ds
# Out:
# <xarray.Dataset> Size: 1GB
# Dimensions:        (latitude: 721, longitude: 1440, depthBelowLandLayer: 4,
#                     isobaricInhPa: 47)
# Coordinates:
#     time           datetime64[ns] 8B 2018-04-25
#     step           timedelta64[ns] 8B 06:00:00
#   * latitude       (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#   * longitude      (longitude) float64 12kB 0.0 0.25 0.5 ... 359.2 359.5 359.8
#     valid_time     datetime64[ns] 8B 2018-04-25T06:00:00
#   * isobaricInhPa  (isobaricInhPa) float64 376B 1.0 2.0 3.0 ... 975.0 1e+03
# Dimensions without coordinates: depthBelowLandLayer
# Data variables: (12/76)
#     tcc            (latitude, longitude) float32 4MB ...
#     st             (depthBelowLandLayer, latitude, longitude) float32 17MB ...
#     soilw          (depthBelowLandLayer, latitude, longitude) float32 17MB ...
#     soill          (depthBelowLandLayer, latitude, longitude) float32 17MB ...
#     t2m            (latitude, longitude) float32 4MB ...
#     sh2            (latitude, longitude) float32 4MB ...
#     ...             ...
#     avg_al         (latitude, longitude) float32 4MB ...
#     landn          (latitude, longitude) float32 4MB ...
#     cnwat          (latitude, longitude) float32 4MB ...
#     sithick        (latitude, longitude) float32 4MB ...
#     duvb           (latitude, longitude) float32 4MB ...
#     cduvb          (latitude, longitude) float32 4MB ...
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             kwbc
#     GRIB_centreDescription:  US National Weather Service - NCEP
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             US National Weather Service - NCEP
#     history:                 2025-05-29T11:17 GRIB to CDM+CF via cfgrib-0.9.1...

# %%
fig, axs = plt.subplots(2, 2, figsize=(10,10), constrained_layout=True)
for key, ax in zip(["tcc", "hcc", "mcc", "lcc"], axs.flatten()):
    ds[key].plot(ax=ax)

# %%
(ds.tcc*3 - (ds["lcc"] + ds["mcc"] + ds["hcc"])).plot()
